# %%
from datasets import load_dataset
ds = load_dataset("oneonlee/cleansed_emocontext")

# %%
df = ds['train'].to_pandas()

# %%
print(df.head(1))
# Out:
#                   turn1                         turn2               turn3  \
# 0  don't worry i'm girl  hmm how do i know if you are  what's your name ?
#
#    label
# 0      0

# %%
sample_df = df.head(3)

# Display the samples in a beautiful table format
import pandas as pd
from IPython.display import display

# Display the table
display(sample_df)
# Out:
#                   turn1                         turn2                 turn3  \
# 0  don't worry i'm girl  hmm how do i know if you are    what's your name ?
# 1          when did i ?    saw many times i think - -  no . i never saw you
# 2                    by              by google chrome        where you live
#
#    label
# 0      0
# 1      3
# 2      0

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30160 entries, 0 to 30159
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   turn1   30138 non-null  object
#  1   turn2   30159 non-null  object
#  2   turn3   28717 non-null  object
#  3   label   30160 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 942.6+ KB
# None

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Step 4: View Class Distribution
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='label')  # or 'emotion' if the label column is named differently
plt.title("Class Distribution")
plt.xticks(rotation=45)
plt.show()

# %%
missing_turn3 = df['turn3'].isnull().sum()
print(f"Number of missing or None 'turn3' rows: {missing_turn3}")
# Out:
# Number of missing or None 'turn3' rows: 1443
